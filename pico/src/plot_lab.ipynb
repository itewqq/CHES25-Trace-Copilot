# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
tinyaes_width = [4095, 3965, 3989, 3988, 3966, 3965, 3965, 3987, 3963]
tinyaes_width = tinyaes_width[:]

ass = 1/6
figsize = plt.figaspect(ass)
fig, ax = plt.subplots(figsize=figsize)

# ax.hist(tinyaes_width, bins=np.arange(min(tinyaes_width), max(tinyaes_width) + 5, 5), color='skyblue', alpha=0.8)
p = ax.bar(np.arange(1,10), tinyaes_width[:])
ax.bar_label(p)
ax.set_title("The number of the 9 round widths in trace (Unit: sampling points)")
ax.set_ylim(3900, np.max(tinyaes_width[:])+20)
# ax.legend()

np.mean(tinyaes_width[1:])
# Out:
# 3973.5
